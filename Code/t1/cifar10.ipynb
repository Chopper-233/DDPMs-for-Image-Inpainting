# %%
import torch
from torch.optim import Adam
from torch.utils.data import DataLoader
from torchvision.datasets.cifar import CIFAR10

import unet
import ddpms
import utils

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}\t".strip().upper() + ": " + (f"{torch.cuda.get_device_name(0)}" if torch.cuda.is_available() else "CPU"))
# Out:
# USING CPU: CPU

# %%
batch_size = 128
num_epochs = 20
learning_rate = 0.001
retrain = False
store_path = "ddpm_cifar_10.pt"

# %%
dataset = CIFAR10("./datasets", download=True, train=True, transform=utils.transform)
loader = DataLoader(dataset, batch_size, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
# view first batch of images
utils.view_batch0(loader)

# %%
# define model
n_steps = 1000
min_beta = 0.0001
max_beta = 0.02
ddpm = ddpms.DDPM_3_32(unet.UNet_3_32(n_steps), n_steps=n_steps, min_beta=min_beta, max_beta=max_beta, device=device, loader=loader, image_chw=(3,32,32))

# %%
# visualise forward process
ddpm.show_forward([.25, 1])

# %%
# train
if retrain: ddpm.train_loop(num_epochs, optim=Adam(ddpm.parameters(), learning_rate), store_path=store_path)

# %%
# load best model and generate images
ddpm.load_state_dict(torch.load(store_path, map_location=device))
_ = ddpm.eval()

# %%
generated = ddpm.generate(n_samples=10)

# %%
utils.view_images(images=generated, rows=1, cols=10)

# %%
real = next(iter(loader))[0]
print(real.shape)
fake = ddpm.generate(n_samples=128)
print(fake.shape)
# Out:
# torch.Size([128, 3, 32, 32])

# %%
ddpm.calculate_frechet(real, fake)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 ddpm.calculate_frechet(real, fake)
#
# File /mnt/c/Users/prana/OneDrive/Documents/University/II/DDPMs-for-Image-Inpainting/Code/t1/ddpms.py:270, in DDPM_3_32.calculate_frechet(self, images_real, images_fake)
#     269 def calculate_frechet(self, images_real, images_fake):
# --> 270     mu_1,std_1 = self.calculate_activation_statistics(images_real)
#     271     mu_2,std_2 = self.calculate_activation_statistics(images_fake)
#     273     fid_value = self.calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
#
# File /mnt/c/Users/prana/OneDrive/Documents/University/II/DDPMs-for-Image-Inpainting/Code/t1/ddpms.py:222, in DDPM_3_32.calculate_activation_statistics(self, images, dims)
#     219 act = np.empty((len(images), dims))
#     221 batch = images.to(self.device)
# --> 222 pred = self.inception(batch)[0]
#     224 # If model output is not scalar, apply global spatial average pooling.
#     225 # This happens if you choose a dimensionality not equal 2048.
#     226 # if pred.size(2) != 1 or pred.size(3) != 1:
#     227 #     pred = adaptive_avg_pool2d(pred, output_size=(1, 1))
#     229 act = pred.cpu().data.numpy().reshape(pred.size(0), -1)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torchvision/models/inception.py:166, in Inception3.forward(self, x)
#     164 def forward(self, x: Tensor) -> InceptionOutputs:
#     165     x = self._transform_input(x)
# --> 166     x, aux = self._forward(x)
#     167     aux_defined = self.training and self.aux_logits
#     168     if torch.jit.is_scripting():
#
# File ~/.local/lib/python3.8/site-packages/torchvision/models/inception.py:105, in Inception3._forward(self, x)
#     103 def _forward(self, x: Tensor) -> Tuple[Tensor, Optional[Tensor]]:
#     104     # N x 3 x 299 x 299
# --> 105     x = self.Conv2d_1a_3x3(x)
#     106     # N x 32 x 149 x 149
#     107     x = self.Conv2d_2a_3x3(x)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torchvision/models/inception.py:405, in BasicConv2d.forward(self, x)
#     404 def forward(self, x: Tensor) -> Tensor:
# --> 405     x = self.conv(x)
#     406     x = self.bn(x)
#     407     return F.relu(x, inplace=True)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same
